# %%
import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)
print(df)


import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)
print(df)


import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)
print(df.head(3))


import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)
print(df.tail(2))


import pandas as pd


data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)
print(df.shape)


import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)
print(df.columns)


import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)
df.info()


import pandas as pd
data = {
    "Name": ["Aarohi", "Rahul", "Sneha", "Amit", "Priya"],
    "Age": [20, 21, 19, 22, 20],
    "City": ["Pune", "Mumbai", "Nagpur", "Nashik", "Kolhapur"],
    "Marks": [85, 78, 92, 74, 88]
}
df = pd.DataFrame(data)


print(df.describe())


import pandas as pd
df = pd.read_csv("students.csv")
print(df)


import pandas as pd
df = pd.read_csv("students.csv")
df.to_csv("students_backup.csv", index=False)
print("DataFrame saved successfully.")


import pandas as pd


df = pd.read_csv("students.csv")
print(df["Name"])


import pandas as pd
df = pd.read_csv("students.csv")
print(df[["Name", "Marks"]])


import pandas as pd
df = pd.read_csv("students.csv")
print(df[df["Marks"] > 80])


import pandas as pd
df = pd.read_csv("students.csv")


print(df[df["Age"] > 20])


import pandas as pd
df = pd.read_csv("students.csv")
print(df[df["City"] == "Pune"])


import pandas as pd


df = pd.read_csv("students.csv")
print(df[(df["Marks"] >= 70) & (df["Marks"] <= 90)])


import pandas as pd
df = pd.read_csv("students.csv")
print(df[(df["City"] == "Mumbai") & (df["Marks"] > 75)])


import pandas as pd
df = pd.read_csv("students.csv")
print(df.sort_values(by="Marks", ascending=True))


import pandas as pd
df = pd.read_csv("students.csv")
print(df.sort_values(by="Marks", ascending=False))


import pandas as pd
df = pd.read_csv("students.csv")
print(df["City"].unique())


import pandas as pd


df = pd.read_csv("students.csv")
print(df["City"].value_counts())


import pandas as pd
df = pd.read_csv("students.csv")
print(df[df.duplicated()])


import pandas as pd
df = pd.read_csv("students.csv")
df = df.drop_duplicates()
print(df)


import pandas as pd


df = pd.read_csv("students.csv")
print(df.isnull().sum())


import pandas as pd
df = pd.read_csv("students.csv")
print(df.isnull().sum())
# Out:
#      Name  Age      City  Marks
# 0  Aarohi   20      Pune     85
# 1   Rahul   21    Mumbai     78
# 2   Sneha   19    Nagpur     92
# 3    Amit   22    Nashik     74
# 4   Priya   20  Kolhapur     88
#      Name  Age      City  Marks
# 0  Aarohi   20      Pune     85
# 1   Rahul   21    Mumbai     78
# 2   Sneha   19    Nagpur     92
# 3    Amit   22    Nashik     74
# 4   Priya   20  Kolhapur     88
#      Name  Age    City  Marks
# 0  Aarohi   20    Pune     85
# 1   Rahul   21  Mumbai     78
# 2   Sneha   19  Nagpur     92
#     Name  Age      City  Marks
# 3   Amit   22    Nashik     74
# 4  Priya   20  Kolhapur     88
# (5, 4)
# Index(['Name', 'Age', 'City', 'Marks'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   City    5 non-null      str
# ...
