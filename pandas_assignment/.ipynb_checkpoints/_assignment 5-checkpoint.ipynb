# %%
import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)
print(student_data)


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)
print(student_data)

import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)
print("First 3 rows :\n",student_data.head(3))


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
     
 "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)
print("Last 2 rows :\n",student_data.tail(2))


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)
print("Shape :",student_data.shape)


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)
print("All Column Names :",student_data.columns)


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]

     }
student_data=pd.DataFrame(data)
print(student_data.info())


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
student_data=pd.DataFrame(data)


print(student_data.describe())


import pandas as pd 
df=pd.read_csv("students.csv")
print(df)


import pandas as pd
df=pd.read_csv("students.csv")
print(df)
df.to_csv("students_backup.csv",index=False)


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
df=pd.DataFrame(data)
print(df["Name"])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
df=pd.DataFrame(data)

print(df[["Name","Age"]])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
  
    "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
df=pd.DataFrame(data)
print(df[df["Marks"] > 80])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
df=pd.DataFrame(data)
print(df[df["Age"] > 20])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
df=pd.DataFrame(data)
print(df[df["City"]=="Pune"])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,65,88,87,89]
     }
df=pd.DataFrame(data)
print(df[(df["Marks"] >= 70) & (df["Marks"] <= 90)])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,95,88,87,89]
     }
df=pd.DataFrame(data)

print(df[(df["Marks"] >75) & (df["City"]=="Mumbai")])


import pandas as pd 

data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,95,88,87,89]
     }
df=pd.DataFrame(data)
print(df.sort_values("Marks"))


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,95,88,87,89]
     }
df=pd.DataFrame(data)
print(df.sort_values("Marks",ascending=False))


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,95,88,87,89]
     }
df=pd.DataFrame(data)
print(df["City"].unique())


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Rahul"],
      "Age":[18,19,18,20,21],
      "City":["Pune","Mumbai","Nanded","Delhi","Nagpur"],
      "Marks":[85,95,88,87,89]
     }
df=pd.DataFrame(data)  
print(df["City"].value_counts())


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Priya"],
      "Age":[18,19,18,20,18],
      "City":["Pune","Mumbai","Nanded","Delhi","Pune"],
  
    "Marks":[85,95,88,87,85]
     }
df=pd.DataFrame(data)
print(df[df.duplicated()])


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Priya"],
      "Age":[18,19,18,20,18],
      "City":["Pune","Mumbai","Nanded","Delhi","Pune"],
      "Marks":[85,95,88,87,85]
     }
df=pd.DataFrame(data)
df.drop_duplicates()


import pandas as pd 
data={"Name":["Priya","Om","Neha","Rohan","Priya"],
      "Age":[18,19,18,20,18],
      "City":["Pune","Mumbai","Nanded","Delhi","Pune"],
      "Marks":[85,95,88,87,85]
     }
df=pd.DataFrame(data)
print(df.isnull().sum())
# Out:
#     Name  Age    City  Marks
# 0  Priya   18    Pune     85
# 1     Om   19  Mumbai     65
# 2   Neha   18  Nanded     88
# 3  Rohan   20   Delhi     87
# 4  Rahul   21  Nagpur     89
#     Name  Age    City  Marks
# 0  Priya   18    Pune     85
# 1     Om   19  Mumbai     65
# 2   Neha   18  Nanded     88
# 3  Rohan   20   Delhi     87
# 4  Rahul   21  Nagpur     89
# First 3 rows :
#      Name  Age    City  Marks
# 0  Priya   18    Pune     85
# 1     Om   19  Mumbai     65
# 2   Neha   18  Nanded     88
# Last 2 rows :
#      Name  Age    City  Marks
# 3  Rohan   20   Delhi     87
# 4  Rahul   21  Nagpur     89
# Shape : (5, 4)
# All Column Names : Index(['Name', 'Age', 'City', 'Marks'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   City    5 non-null      str
# ...
